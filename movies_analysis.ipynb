# %%
import pandas as pd

# %%
db = pd.read_csv("movies.csv", lineterminator='\n') #create dataframe

# %%
db.head()
# Out:
#    adult backdrop_path belongs_to_collection  budget  \
# 0  False           NaN                   NaN       0
# 1  False           NaN                   NaN       0
# 2  False           NaN                   NaN       0
# 3  False           NaN                   NaN       0
# 4  False           NaN                   NaN       0
#
#                                               genres homepage      id  \
# 0  [{'id': 99, 'name': 'Documentary'}, {'id': 28,...      NaN  684428
# 1  [{'id': 99, 'name': 'Documentary'}, {'id': 28,...      NaN  684431
# 2                [{'id': 99, 'name': 'Documentary'}]      NaN  174615
# 3                [{'id': 99, 'name': 'Documentary'}]      NaN  371610
# 4                                                 []      NaN  344225
#
#      imdb_id original_language  \
# 0  tt0371396                en
# 1  tt0365467                en
# 2  tt0439783                en
# 3        NaN                en
# 4  tt0274085                en
#
# ...

# %%
db.shape
# Out:
# (20, 25)

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  20 non-null     bool
#  1   backdrop_path          5 non-null      object
#  2   belongs_to_collection  4 non-null      object
#  3   budget                 20 non-null     int64
#  4   genres                 20 non-null     object
#  5   homepage               1 non-null      object
#  6   id                     20 non-null     int64
#  7   imdb_id                17 non-null     object
#  8   original_language      20 non-null     object
#  9   original_title         20 non-null     object
#  10  overview               20 non-null     object
#  11  popularity             20 non-null     float64
#  12  poster_path            15 non-null     object
#  13  production_companies   20 non-null     object
# ...

# %%
db.describe()
# Out:
#              budget             id  popularity       revenue     runtime  \
# count  2.000000e+01      20.000000   20.000000  2.000000e+01   20.000000
# mean   1.815000e+07  421678.700000   10.311050  8.135526e+07   72.650000
# std    4.722875e+07  271752.412918   16.596384  2.062981e+08   89.407568
# min    0.000000e+00     603.000000    0.600000  0.000000e+00    0.000000
# 25%    0.000000e+00  209775.000000    1.673500  0.000000e+00    6.750000
# 50%    0.000000e+00  504843.000000    2.377000  0.000000e+00   29.000000
# 75%    0.000000e+00  684505.500000    8.530750  0.000000e+00  124.500000
# max    1.500000e+08  696109.000000   60.475000  7.385997e+08  360.000000
#
#        vote_average    vote_count
# count     20.000000     20.000000
# mean       5.000000   1572.100000
# std        3.153778   4329.339452
# min        0.000000      0.000000
# 25%        3.000000      0.750000
# 50%        6.650000      2.000000
# 75%        7.225000     14.500000
# ...
